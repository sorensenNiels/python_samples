# %%
# !uv sync
# !uv pip install pandas


async def hello_world():
    print("Hello World!")


await hello_world()
# Out:
# Resolved 124 packages in 3ms
# Audited 118 packages in 0.14ms
# Using Python 3.13.3 environment at: /workspaces/python_samples/.venv
# Audited 1 package in 1ms
# Hello World!
